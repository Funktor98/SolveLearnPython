# %% [markdown]
# # Рекурсия

# %% [markdown]
# <img src="http://lurkmore.so/images/d/dc/Recursion6302.jpg" width="30%"/>

# %% [markdown]
# https://ru.wikipedia.org/wiki/Рекурсия <br/>
# https://ru.wikipedia.org/wiki/Рекурсия#В_программировании

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <img src="https://daruse.ru/assets/img/blog/stati/content/rekurs.jpg" width="30%"/>
# Еще про рекурсию
# https://javarush.ru/quests/lectures/questharvardcs50.level04.lecture02

# %% [markdown]
# - Возможности рекурсии совпадают с возможностями циклов (об этом будет задача)

# %%
import sys
sys.setrecursionlimit(10000)
sys.getrecursionlimit()
# Out:
# 10000

# %% [markdown]
# ### Задачи

# %% [markdown]
# В следующем блоке задач запрещено использовать циклы и списки, если отдельно не оговорено обратное. (А в некоторых задачах можно обойтись и без рекурсии, если подумать) <br/>
# - *Можно (и нужно) объявлять новые функции.*

# %% [markdown]
# **Задача 1.** Напишите функцию, которая вычисляет сумму первых $n$ чисел по введенному натуральному числу $n$.

# %%
def sum_n(n):
    pass

# %% [markdown]
# **Задача 2.** Напишите функцию, вычисляющую произведение натуральных нечетных чисел, не превосходящих $n$

# %%
def fact_odd(n):
    pass

# %% [markdown]
# **Задача 3.** Напишите функцию, которая выводит первые $n$ натуральных чисел

# %%
def print_range(n):
    pass

# %% [markdown]
# **Задача 4.** Напишите функцию, проверяющую, является ли число степенью двойки

# %%
def is_power_of_2(n):
    pass

# %% [markdown]
# **Задача 5.** Напишите функцию, вычисляющую сумму цифр числа

# %%
def sum_of_digits(n):
    pass

# %% [markdown]
# **Задача 6.** Напишите функцию, печатающую цифры числа в обратном порядке через пробел.

# %%
def print_digits_reversed(n):
    pass

# %% [markdown]
# **Задача 7.** Напишите функцию, печатающую цифры числа в обычном порядке через пробел.

# %%
def print_digits(n):
    pass

# %% [markdown]
# **Задача 8.** Напишите функцию, проверяющую, является ли данная строка палиндромом. В этой задаче запрещено использовать срезы строки с шагом, отличным от 1.

# %%
def is_palindrom(word):
    pass

# %% [markdown]
# <img src="http://lurkmore.so/images/4/47/Recursy.jpg"/>

# %% [markdown]
# #### В следующих задачах запрещено использовать глобальные переменные.

# %% [markdown]
# **Задача 9.** Напишите функцию, выводящую максимум введенной последовательности чисел (числа вводятся через пробел, разрешается сохранить их в списке)

# %% [markdown]
# **Задача 10.**  Напишите функцию, выводящую второе по величине число во введенной последовательности чисел (числа вводятся через пробел, разрешается сохранить их в списке)

# %% [markdown]
# **Задача 11.** Напишите функцию, выводящую среднее арифметическое введенной последовательности чисел (числа вводятся через пробел, разрешается сохранить их в списке)

# %% [markdown]
# **Задача 12.** Даны числа $a$ и $b$. Определите, сколько существует последовательностей из $a$ нулей и $b$ единиц, в которых никакие два нуля не стоят рядом.

# %% [markdown]
# **Задача 13.** Дано число $n$, десятичная запись которого не содержит нулей. Получите число, записанное теми же цифрами, но в противоположном порядке. Нельзя пользоваться строками.

# %% [markdown]
# **Задача 14.** **[Цикл for].** Напишите функцию, на вход которой подается функция $f$, принимающая в качестве параметра одно натуральное число $-$ $i$, и натуральное число $n$. Функция должна запускать $f$ для каждого из аргументов от $1$ до $n$. <br/>
# Например:
# ```
# def f(x):
#     print(x, end=' ')
#
# for_realization(f, 5)
# print()
# ```
# напечатает <br>
# ```
# 1 2 3 4 5
#
# ```

# %%
def for_realization(function, n):
    pass

# %% [markdown]
# ## ---
# Так как всё, что можно сделать с помощью цикла **while**, можно также сделать с помощью цикла **for** (а цикл **for** реализуется рекурсией), рекурсией можно заменить любой цикл.
# ## ---

# %% [markdown]
# **Задача 15.** Дана монотонная последовательность, в которой каждое натуральное число $k$ встречается ровно $k$ раз: $1, 2, 2, 3, 3, 3, 4, 4, 4, 4, ...$
# По данному натуральному $n$ выведите первые $n$ членов этой последовательности. <br>

# %% [markdown]
# **Задача 16.** Головоломка “Ханойские башни” состоит из трех стержней, пронумерованных числами $1$, $2$, $3$. На стержень $1$ надета пирамидка из $n$ дисков различного диаметра в порядке возрастания диаметра. Диски можно перекладывать с одного стержня на другой по одному, при этом диск нельзя класть на диск меньшего диаметра. Необходимо переложить всю пирамидку со стержня $1$ на стержень $3$ за минимальное число перекладываний.
# ![image.png](attachment:image.png)
# Например, строка 1 2 3 означает перемещение диска номер 1 со стержня 2 на стержень 3. В одной строке печатается одна команда. Диски пронумерованы числами от 1 до n в порядке возрастания диаметров. <br> <br>
# **Входные данные** <br>
# - Вводится натуральное число $n$. <br>
#
# **Выходные данные** <br>
# - Программа должна вывести минимальный (по количеству произведенных операций) способ перекладывания пирамидки из данного числа дисков. <br> <br>
#
# **Пример** для $n$ = 2 правильный ответ следующий <br>
# ```
# 1 1 2
# 2 1 3
# 1 2 3
# ```

# %%
def hanoi(n):
    pass

# %% [markdown]
# **Задача 17.** Необходимо решить предыдущую задачу при условии, что диски можно перекладывать только *'слева направо'*, то есть с $1$ на $2$, с $2$ на $3$, с $3$ на $1$.

# %% [markdown]
# **Задача 18.** В Ханое несправедливо запретили класть самый маленький диск (номер 1) на средний колышек (номер 2). Решите *Задачу 16* с учетом этого ограничения. В этом случае не нужно искать решение с наименьшим числом перекладываний.

# %% [markdown]
# <img src="attachment:image.png" width="700" />
